# %%
#!/usr/bin/python3.10

# %% [markdown]
# Prerequisites: pandas, xlrd, matplotlib, rpy2

# %% [markdown]
# # HSMC modelling: switching linear mixed models

# %% [markdown]
# ## Configuration
# ### It is assumed that this notebook is run from StructureAnalysis/sequence_analysis/tutorials

# %% [markdown]
# **Import OpenAlea packages**

# %%
from openalea.stat_tool import _stat_tool
from openalea.sequence_analysis import _sequence_analysis
from openalea.sequence_analysis.hidden_semi_markov import HiddenSemiMarkov
from openalea.sequence_analysis.simulate import Simulate
from openalea.sequence_analysis.data_transform import Thresholding

from openalea.stat_tool.data_transform import *
from openalea.stat_tool.cluster import Cluster
from openalea.stat_tool.cluster import Transcode, Cluster

import openalea.stat_tool.plot #import DISABLE_PLOT
# openalea.stat_tool.plot.DISABLE_PLOT = True
from openalea.stat_tool.plot import DISABLE_PLOT
DISABLE_PLOT = False

import os

from openalea.stat_tool.output import plot, Plot

plot.DISABLE_PLOT = DISABLE_PLOT

from openalea.stat_tool.plot import get_plotter, mplotlib

# %% [markdown]
# ##### Check pandas version

# %%
# print pd.__version__

# %%
import xlrd
xlrd.__version__
# Out:
# '2.0.1'

# %% [markdown]
# ##### Enabling R extensions

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# #####  Place variables in markdown outputs

# %%
from IPython.display import Markdown
from IPython.core.magic import register_cell_magic


@register_cell_magic
def markdown(line, cell):
    return Markdown(cell.format(**globals()))

# %% [markdown]
# ## Determining if images have to be saved (not used for the moment)

# %% [markdown]
# ## Loading and preparing data

# %%
import sys, os

# %%
sys.path
# Out:
# ['/home/jdurand/devlp/Git/openalea/StructureAnalysis',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python310.zip',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python3.10',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python3.10/lib-dynload',
#  '',
#  '/home/jdurand/.local/lib/python3.10/site-packages',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python3.10/site-packages',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python3.10/site-packages/OpenAlea.SConsX-2.4.0-py3.9.egg',
#  '/home/jdurand/devlp/Git/openalea/StructureAnalysis/sequence_analysis/src',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python3.10/site-packages/OpenAlea.StatTool-2.0.0-py3.10-linux-x86_64.egg',
#  '/home/jdurand/devlp/Git/openalea/StructureAnalysis/stat_tool/src',
#  '/home/jdurand/miniforge3/envs/openalea/lib/python3.10/site-packages/openalea.deploy-3.1.2-py3.10.egg']

# %%
sys.path.append(".." + os.sep + "tutorials")

# %%
# TODO: fix this
# get_shared_data("data")

# %%
from pathlib import Path
data_path = Path(openalea.sequence_analysis.__path__[0])
data_path = str(Path.joinpath(data_path.parent.parent.parent.absolute(), "share","data"))

# %% [markdown]
# **Read an existing HSMC model**

# %%
model_file = "switching_lmm_irred.hsc"

hsm = HiddenSemiMarkov(data_path + os.sep + model_file)

# %%
print(hsm.display())
# Out:
# HIDDEN_SEMI-MARKOV_CHAIN
#
# 3 STATES
#
# INITIAL_PROBABILITIES
# 1    0    0
#
# TRANSITION_PROBABILITIES
# 0    0.8  0.2
# 0.4  0    0.6
# 0.8  0.2  0
#
# recurrent class: states 0 1 2
#
# time up to the first occurrence of state 0 distribution
# mean: 0   median: 0   mode: 0
# variance: 0   standard deviation: 0
#
# time up to the first occurrence of state 1 distribution
# mean: 6.25102   median: 4   mode: 3
# variance: 48.8701   standard deviation: 6.99072   lower quartile: 2   upper quartile: 6
#
# time up to the first occurrence of state 2 distribution
# mean: 12.1464   median: 10   mode: 8
# variance: 82.5395   standard deviation: 9.08513   lower quartile: 6   upper quartile: 16
#
# state 0 recurrence time distribution
# mean: 4.62258   median: 1   mode: 1
# variance: 59.1125   standard deviation: 7.68847   lower quartile: 1   upper quartile: 5
#
# state 1 recurrence time distribution
# mean: 2.82455   median: 1   mode: 1
# variance: 31.2908   standard deviation: 5.59382   lower quartile: 1   upper quartile: 1
#
# state 2 recurrence time distribution
# mean: 2.32602   median: 1   mode: 1
# variance: 23.4969   standard deviation: 4.84736   lower quartile: 1   upper quartile: 1
#
# STATE 0 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 10   PROBABILITY : 0.8
# mean: 3.5   median: 3   mode: 3
# variance: 3.125   standard deviation: 1.76777   lower quartile: 2   upper quartile: 5
# coefficient of skewness: 0.848528   coefficient of kurtosis: 0.92
# coefficient of variation: 0.505076
#
# state 0 forward sojourn time distribution
# mean: 2.69639   median: 2   mode: 1
# variance: 2.74662   standard deviation: 1.65729   lower quartile: 1   upper quartile: 4
#
# STATE 1 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 5   PROBABILITY : 0.5
# mean: 6   median: 5.5   mode: 4.5
# variance: 10   standard deviation: 3.16228   lower quartile: 4   upper quartile: 8
# coefficient of skewness: 0.948683   coefficient of kurtosis: 1.3
# coefficient of variation: 0.527046
#
# state 1 forward sojourn time distribution
# mean: 4.33324   median: 4   mode: 1
# variance: 8.88643   standard deviation: 2.98101   lower quartile: 2   upper quartile: 6
#
# STATE 2 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 2   PROBABILITY : 0.2
# mean: 9   median: 8   mode: 4.5
# variance: 40   standard deviation: 6.32456   lower quartile: 4   upper quartile: 12
# coefficient of skewness: 1.42302   coefficient of kurtosis: 3.025
# coefficient of variation: 0.702728
#
# state 2 forward sojourn time distribution
# mean: 7.22191   median: 6   mode: 1
# variance: 35.0422   standard deviation: 5.91964   lower quartile: 3   upper quartile: 10
#
# number of runs of state 0 per length 20 sequence distribution
# mean: 1.88642   median: 2   mode: 2
# variance: 0.447351   standard deviation: 0.668843   lower quartile: 1   upper quartile: 2
# coefficient of skewness: 0.272345   coefficient of kurtosis: -0.270728
#
# number of runs of state 1 per length 20 sequence distribution
# mean: 1.4483   median: 1   mode: 1
# variance: 0.471655   standard deviation: 0.686771   lower quartile: 1   upper quartile: 2
# coefficient of skewness: 0.0490001   coefficient of kurtosis: -0.139182
#
# number of runs of state 2 per length 20 sequence distribution
# mean: 0.995393   median: 1   mode: 1
# variance: 0.340931   standard deviation: 0.583893   lower quartile: 1   upper quartile: 1
# coefficient of skewness: 0.137317   coefficient of kurtosis: 0.411462
#
# number of occurrences of state 0 per length 20 sequence distribution
# mean: 6.23681   median: 6   mode: 6
# variance: 7.60345   standard deviation: 2.75744   lower quartile: 4   upper quartile: 8
# coefficient of skewness: 0.359404   coefficient of kurtosis: -0.23107
#
# number of occurrences of state 1 per length 20 sequence distribution
# mean: 7.52613   median: 8   mode: 7
# variance: 15.8118   standard deviation: 3.9764   lower quartile: 5   upper quartile: 10
# coefficient of skewness: -0.0283943   coefficient of kurtosis: -0.608324
#
# number of occurrences of state 2 per length 20 sequence distribution
# mean: 6.23706   median: 6   mode: 0
# variance: 21.0485   standard deviation: 4.58787   lower quartile: 2   upper quartile: 10
# coefficient of skewness: 0.332499   coefficient of kurtosis: -0.699809
#
# 1 OUTPUT_PROCESS
#
# OUTPUT_PROCESS 1 : CONTINUOUS_PARAMETRIC
#
# STATE 0 OBSERVATION_MODEL
# LINEAR_MODEL   INTERCEPT : 0   SLOPE : 0   STANDARD_DEVIATION : 1
#
# STATE 1 OBSERVATION_MODEL
# LINEAR_MODEL   INTERCEPT : 3   SLOPE : 3   STANDARD_DEVIATION : 40
#
# STATE 2 OBSERVATION_MODEL
# LINEAR_MODEL   INTERCEPT : 6   SLOPE : 6   STANDARD_DEVIATION : 400

# %%
hsm.plot("Intensity", 0)

# %%
hsm.plot("Counting", 0)

# %%
hsm.plot()
# Out:
# Warning. Empty data.
# Warning. Empty data.
# Warning. Empty data.
# Warning. Empty data.

# %%
hsm.plot("Sojourn", 0)

# %% [markdown]
# **Simulate sequences**

# %%
from openalea.sequence_analysis import Simulate

# %%
from openalea.stat_tool.distribution import set_seed
set_seed(0)

# %% [markdown]
# Simulate *nb_seq* sequences with length *seq_length*

# %%
nb_seq = 30
seq_length = 100
seq = hsm.simulation_nb_sequences(nb_seq, seq_length, True)
assert(len(seq) == nb_seq)
assert(len(seq[0]) == seq_length)
# NB: hsm has 1 output process but simulation includes the hidden state
assert(len(seq[0][1]) == 2)
# Out:
# variable 2 - bin width: 9
#
# N.o. initial states in parallel: 0
#
# ERROR: 0 3.80307 inf
#
# ERROR: 1 6.7303 inf
#
# ERROR: 2 2.48656 inf
#
# ERROR: 3 3.75808 inf
#
# ERROR: 4 4.25691 inf
#
# ERROR: 6 4.28781 inf
#
# ERROR: 7 5.85445 inf
#
# ERROR: 8 4.62564 inf
#
# ERROR: 9 4.56262 inf
#
# ERROR: 10 5.48662 inf
#
# ERROR: 11 4.08792 inf
#
# ERROR: 12 4.15641 inf
#
# ERROR: 13 4.4601 inf
#
# ERROR: 14 3.23092 inf
#
# ERROR: 15 3.25497 inf
#
# ERROR: 16 5.41913 inf
#
# ERROR: 17 3.98085 inf
#
# ERROR: 18 2.96856 inf
#
# ERROR: 19 4.88714 inf
#
# ERROR: 20 5.09121 inf
#
# ERROR: 21 2.99786 inf
#
# ERROR: 22 3.92551 inf
#
# ERROR: 23 3.86456 inf
#
# ERROR: 24 2.87996 inf
#
# ERROR: 25 4.35696 inf
#
# ERROR: 26 6.02623 inf
#
# ERROR: 27 3.0787 inf
#
# ERROR: 28 2.86343 inf
#
# ERROR: 29 5.66375 inf

# %%
from openalea.sequence_analysis import Sequences, _MarkovianSequences

# %%
seqm = _MarkovianSequences(seq)

# %%
print(seqm.display())
# Out:
# 2 VARIABLES
#
# VARIABLE 1 : STATE   (3 states)
#
# state frequency distribution - sample size: 3000
# mean: 1.168   median: 1   mode: 2
# variance: 0.595975   standard deviation: 0.771994   lower quartile: 1   upper quartile: 2
#
#    | frequency
# 0   684
# 1  1128
# 2  1188
#
# time up to the first occurrence of state 0 frequency distribution - sample size: 0
#
# time up to the first occurrence of state 1 frequency distribution - sample size: 30
# mean: 5.8   median: 4   mode: 2.5
# variance: 30.9931   standard deviation: 5.56714   lower quartile: 2   upper quartile: 6
#
# time up to the first occurrence of state 2 frequency distribution - sample size: 30
# mean: 11.8   median: 10.5   mode: 9
# variance: 48.9931   standard deviation: 6.99951   lower quartile: 7   upper quartile: 16
#
# state 0 recurrence time frequency distribution - sample size: 654
# mean: 4.19572   median: 1   mode: 1
# variance: 50.3322   standard deviation: 7.09452   lower quartile: 1   upper quartile: 3
#
# state 1 recurrence time frequency distribution - sample size: 1098
# mean: 2.38525   median: 1   mode: 1
# variance: 21.3455   standard deviation: 4.62012   lower quartile: 1   upper quartile: 1
#
# state 2 recurrence time frequency distribution - sample size: 1158
# mean: 2.10967   median: 1   mode: 1
# variance: 18.5575   standard deviation: 4.30785   lower quartile: 1   upper quartile: 1
#
# state 0 sojourn time frequency distribution - sample size: 193
# mean: 3.46114   median: 3   mode: 2
# variance: 3.17687   standard deviation: 1.78238   lower quartile: 2   upper quartile: 5
#
# final run - state 0 sojourn time frequency distribution - sample size: 6
# mean: 2.66667   median: 3   mode: 1
# variance: 1.86667   standard deviation: 1.36626   lower quartile: 1   upper quartile: 4
#
# state 1 sojourn time frequency distribution - sample size: 175
# mean: 6.22857   median: 6   mode: 6
# variance: 10.6371   standard deviation: 3.26146   lower quartile: 4   upper quartile: 8
#
# final run - state 1 sojourn time frequency distribution - sample size: 9
# mean: 4.22222   median: 3   mode: 3
# variance: 10.6944   standard deviation: 3.27024   lower quartile: 3   upper quartile: 5
#
# state 2 sojourn time frequency distribution - sample size: 123
# mean: 8.97561   median: 8   mode: 4
# variance: 31.7617   standard deviation: 5.63575   lower quartile: 4   upper quartile: 12
#
# final run - state 2 sojourn time frequency distribution - sample size: 15
# mean: 5.6   median: 4   mode: 2
# variance: 20.2571   standard deviation: 4.50079   lower quartile: 2   upper quartile: 8
#
# number of runs of state 0 per sequence frequency distribution - sample size: 30
# mean: 6.63333   median: 7   mode: 6.5
# variance: 2.24023   standard deviation: 1.49674   lower quartile: 6   upper quartile: 8
# coefficient of skewness: -0.243046   coefficient of kurtosis: -0.308649
#
# number of runs of state 1 per sequence frequency distribution - sample size: 30
# mean: 6.13333   median: 6   mode: 5.5
# variance: 1.84368   standard deviation: 1.35782   lower quartile: 5   upper quartile: 7
# coefficient of skewness: 0.716403   coefficient of kurtosis: -0.21636
#
# number of runs of state 2 per sequence frequency distribution - sample size: 30
# mean: 4.6   median: 4.5   mode: 4.5
# variance: 1.62759   standard deviation: 1.27577   lower quartile: 4   upper quartile: 5
# coefficient of skewness: 0.40141   coefficient of kurtosis: -0.891023
#
# number of occurrences of state 0 per sequence frequency distribution - sample size: 30
# mean: 22.8   median: 24   mode: 26
# variance: 34.9931   standard deviation: 5.9155   lower quartile: 19   upper quartile: 26
# coefficient of skewness: -0.421372   coefficient of kurtosis: -0.159762
#
# number of occurrences of state 1 per sequence frequency distribution - sample size: 30
# mean: 37.6   median: 37.5   mode: 40
# variance: 61.4897   standard deviation: 7.84153   lower quartile: 33   upper quartile: 40
# coefficient of skewness: 0.467538   coefficient of kurtosis: -0.0604376
#
# number of occurrences of state 2 per sequence frequency distribution - sample size: 30
# mean: 39.6   median: 38.5   mode: 42
# variance: 110.938   standard deviation: 10.5327   lower quartile: 34   upper quartile: 46
# coefficient of skewness: 0.166143   coefficient of kurtosis: 0.185536
#
# VARIABLE 2 : REAL   (minimum value: -1180.34, maximum value: 1458.58)
#
# sample size: 3000
# mean: 185.538   median: 124.284
# variance: 93991.2   standard deviation: 306.58   lower quartile: 0.35055   upper quartile: 285.292
#
# sequence length frequency distribution - sample size: 30
# mean: 100   median: 100   mode: 100
# variance: 0   standard deviation: 0
#
# cumulative length: 3000

# %%
# Print first simulated sequence.
# First variable is the simulated state
print(seq[0][0:10])
# Out:
# [[0, 1.0711349395988758], [0, 1.024717453524048], [0, 0.3148538711429429], [0, -0.29399278483251934], [0, -0.5315045188658751], [1, 15.75941836921026], [1, 56.43665832499077], [1, 21.99156487759762], [1, 16.117272328555092], [2, 212.15583278791865]]

# %% [markdown]
# Discard variable 1 (state)

# %% [markdown]
# ## Simulation

# %%
set_seed(0)
nb_seq = 30
seq_length = 100
from openalea.stat_tool import NegativeBinomial
d = NegativeBinomial(1, 10., 0.5)

# %%
hsmd = hsm.simulation_nb_sequences(nb_seq, seq_length, True)
assert(len(seq) == nb_seq)
assert(len(seq[0]) == seq_length)
# NB: hsm has 1 output process but simulation includes the hidden state
assert(len(seq[0][1]) == 2)
# Out:
# variable 2 - bin width: 9
#
# N.o. initial states in parallel: 0
#
# ERROR: 0 3.80307 inf
#
# ERROR: 1 6.7303 inf
#
# ERROR: 2 2.48656 inf
#
# ERROR: 3 3.75808 inf
#
# ERROR: 4 4.25691 inf
#
# ERROR: 6 4.28781 inf
#
# ERROR: 7 5.85445 inf
#
# ERROR: 8 4.62564 inf
#
# ERROR: 9 4.56262 inf
#
# ERROR: 10 5.48662 inf
#
# ERROR: 11 4.08792 inf
#
# ERROR: 12 4.15641 inf
#
# ERROR: 13 4.4601 inf
#
# ERROR: 14 3.23092 inf
#
# ERROR: 15 3.25497 inf
#
# ERROR: 16 5.41913 inf
#
# ERROR: 17 3.98085 inf
#
# ERROR: 18 2.96856 inf
#
# ERROR: 19 4.88714 inf
#
# ERROR: 20 5.09121 inf
#
# ERROR: 21 2.99786 inf
#
# ERROR: 22 3.92551 inf
#
# ERROR: 23 3.86456 inf
#
# ERROR: 24 2.87996 inf
#
# ERROR: 25 4.35696 inf
#
# ERROR: 26 6.02623 inf
#
# ERROR: 27 3.0787 inf
#
# ERROR: 28 2.86343 inf
#
# ERROR: 29 5.66375 inf

# %%
obs = hsmd.select_variable([2], True)

# %%
seqm = _MarkovianSequences(obs)

# %% [markdown]
# ### Add index to seqm, index is used as covariate for simulation / estimation

# %%
from openalea.sequence_analysis.sequences import IndexParameterType

index = []
for u in range(nb_seq):
    indexut = []
    indexut.append([d.simulation()])
    for t  in range(1, seq_length):
        indexut.append([indexut[-1][-1]+d.simulation()])
    index.append(indexut)
seq_index = Sequences(index)    
seq_index_markov = _MarkovianSequences(seq_index)
seq_merge = seqm.merge_variable([seq_index_markov], 1)
seq_index = seq_merge.set_variable_as_index_parameter(2, "TIME")
seq_index_markov2 = _MarkovianSequences(seq_index)
assert IndexParameterType(seq_index_markov2)=='TIME'
for u in range(nb_seq):
    for t  in range(0, seq_length):
        assert(int(seq_index_markov2.get_index_parameter(u,t)) == index[u][t][0])
# Out:
# variable 1 - bin width: 9

# %%
# Resimulate with new index
hsmd = hsm.semi_markov_switching_lm_simulation(1, seq_index_markov2, openalea.stat_tool.I_DEFAULT, True);
# Out:
# variable 2 - bin width: 9
#
# variable 2 - bin width: 28
#
# N.o. initial states in parallel: 0
#
# ERROR: 0 1.19432 inf
#
# ERROR: 1 0.967168 inf
#
# ERROR: 2 1.60962 inf
#
# ERROR: 4 0.595698 inf
#
# ERROR: 5 0.861735 inf
#
# ERROR: 6 0.613445 inf
#
# ERROR: 7 0.958922 inf
#
# ERROR: 8 0.122778 inf
#
# ERROR: 9 0.830657 inf
#
# ERROR: 10 0.372132 inf
#
# ERROR: 11 1.41769 inf
#
# ERROR: 12 1.68658 inf
#
# ERROR: 13 1.12366 inf
#
# ERROR: 14 0.419199 inf
#
# ERROR: 15 0.737413 inf
#
# ERROR: 16 1.02234 inf
#
# ERROR: 17 0.0700168 inf
#
# ERROR: 18 0.750965 inf
#
# ERROR: 19 0.213705 inf
#
# ERROR: 20 1.21809 inf
#
# ERROR: 21 0.925011 inf
#
# ERROR: 22 1.39889 inf
#
# ERROR: 23 0.754654 inf
#
# ERROR: 24 0.483673 inf
#
# ERROR: 25 0.0940551 inf
#
# ERROR: 26 0.519552 inf
#
# ERROR: 27 0.440012 inf
#
# ERROR: 28 0.33315 inf
#
# ERROR: 29 0.434346 inf

# %% [markdown]
# ### Plot index and simulated values per state

# %%
values = {}
for u in range(hsmd.nb_sequence):
    for t in range(len(hsmd[u])):
        state = hsmd[u][t][0]
        if state in values.keys():
            values[state][0] += [hsmd.get_index_parameter(u,t)] # predictor
            # values[state][0] += [index[u][t][0]] # predictor
            values[state][1] += [hsmd[u][t][1]] # simulated value
        else:
            values[state] = [[],[]]
nb_states = len(values.keys())
import matplotlib.pyplot as plt       
import numpy as np
fig, subfigs = plt.subplots(int(np.ceil(nb_states / 2)), 2) 
for k in values.keys():    
    subfigs[int(k/2)][k%2].plot(values[k][0],values[k][1],'o')
plt.show()

# %% [markdown]
# ### Plot one sequence with state

# %%
s = 0
state_s = []
obs_s = []
cov_s = []
for t in range(len(hsmd[s])):
    state_s += [hsmd[s][t][0]]
    obs_s += [hsmd[s][t][1]]
    cov_s += [hsmd.get_index_parameter(s,t)]

state_s = np.array(state_s)
obs_s = np.array(obs_s)
cov_s = np.array(cov_s)
plt.plot(obs_s, color=(0.9, 0.9, 0.9))
sstate_s = set(state_s)
for k in sstate_s:
    cl = float(k)
    cl = np.array([cl, 15*cl, 20*cl]) / (20*(nb_states-1))
    plt.plot(np.arange(0, len(hsmd[s]))[state_s==k], obs_s[state_s==k],  'o', 
             color=cl, label="state " + str(k))
plt.plot(cov_s, color="red", label="covariate")
plt.legend()
plt.show()

# %%
all_state_s = []
all_obs_s = []
all_cov_s = []
for s in range(len(hsmd)):
    for t in range(len(hsmd[s])):
        all_state_s += [hsmd[s][t][0]]
        all_obs_s += [hsmd[s][t][1]]
        all_cov_s += [hsmd.get_index_parameter(s,t)]

all_state_s = np.array(all_state_s)
all_obs_s = np.array(all_obs_s)
all_cov_s = np.array(all_cov_s)
plt.plot(all_cov_s, all_obs_s, 'o', color=(0.9, 0.9, 0.9))
for k in sstate_s:
    cl = float(k)
    cl = np.array([cl, 15*cl, 20*cl]) / (20*(nb_states-1))
    plt.plot(all_cov_s[all_state_s==k], all_obs_s[all_state_s==k],  'o', 
             color=cl, label="state " + str(k))

plt.xlabel("covariate")
plt.ylabel("observations")
plt.legend()
plt.show()

# %%
cl
# Out:
# array([0.05, 0.75, 1.  ])

# %%
np.arange(0, len(hsmd[s]))[state_s==0]
# Out:
# array([ 0, 12, 13, 30, 31, 38, 39, 40, 41, 47, 48, 49, 50, 51, 52, 53, 64,
#        65, 72, 73, 74, 75, 96, 97, 98])

# %% [markdown]
# ### Reestimate model

# %%
from openalea.sequence_analysis import Estimate
seq_estim = hsmd.select_variable([2], True);
hsmc_est_file = Estimate(seq_estim, "HIDDEN_SEMI-MARKOV", hsm, Nbiteration=300)
# Out:
# 0
# iteration 1   log-likelihood for the observed sequences: -16898.3
# iteration 2   log-likelihood for the observed sequences: -16891
# iteration 3   log-likelihood for the observed sequences: -16891
# iteration 4   log-likelihood for the observed sequences: -16891
#
# 4 iterations
#
# complete/censored state occupancy weights
# state 0: 199.924, 9  (0.956922, 0.0430779)
# state 1: 187.39, 10  (0.949339, 0.050661)
# state 2: 128.614, 11  (0.921211, 0.0787885)
#
# N.o. initial states in parallel: 0
#
# ERROR: 0 1.15047 inf
#
# ERROR: 1 0.991238 inf
#
# ERROR: 2 1.54302 inf
#
# ERROR: 3 0.382284 inf
#
# ERROR: 4 0.569538 inf
#
# ERROR: 5 0.762657 inf
#
# ERROR: 6 0.635904 inf
#
# ERROR: 7 0.837652 inf
#
# ERROR: 8 0.126471 inf
#
# ERROR: 9 0.802854 inf
#
# ERROR: 10 0.30887 inf
#
# ERROR: 11 1.32172 inf
#
# ERROR: 12 1.69704 inf
#
# ERROR: 13 1.14722 inf
#
# ERROR: 14 0.373237 inf
#
# ERROR: 15 0.701812 inf
#
# ERROR: 16 0.975776 inf
#
# ERROR: 17 0.0689797 inf
#
# ERROR: 18 0.774401 inf
#
# ERROR: 19 0.206215 inf
#
# ERROR: 20 1.21528 inf
#
# ERROR: 21 0.88962 inf
#
# ERROR: 22 1.40118 inf
#
# ERROR: 23 0.676442 inf
#
# ERROR: 24 0.471246 inf
#
# ERROR: 25 0.0921653 inf
#
# ERROR: 26 0.482937 inf
#
# ERROR: 27 0.433291 inf
#
# ERROR: 28 0.304617 inf
#
# ERROR: 29 0.405809 inf
#
# log-likelihood for the state sequences: -16899.2
#
# posterior state sequence probability
# sequence 1: 0.607149
# sequence 2: 0.730781
# sequence 3: 0.469163
# sequence 4: 0.908367
# sequence 5: 0.853393
# sequence 6: 0.840592
# sequence 7: 0.828808
# sequence 8: 0.816037
# sequence 9: 0.983249
# sequence 10: 0.774217
# sequence 11: 0.937223
# sequence 12: 0.64686
# sequence 13: 0.340953
# sequence 14: 0.631038
# sequence 15: 0.925275
# sequence 16: 0.795009
# sequence 17: 0.592934
# sequence 18: 0.989041
# sequence 19: 0.741711
# sequence 20: 0.955558
# sequence 21: 0.640471
# sequence 22: 0.65609
# sequence 23: 0.486634
# sequence 24: 0.759552
# sequence 25: 0.883722
# sequence 26: 0.987751
# sequence 27: 0.896082
# sequence 28: 0.895507
# sequence 29: 0.926046
# sequence 30: 0.905752

# %%
print(hsmc_est_file.display())
# Out:
# HIDDEN_SEMI-MARKOV_CHAIN
#
# 3 STATES
#
# INITIAL_PROBABILITIES
# 1         0         0
#
# TRANSITION_PROBABILITIES
# 0         0.857645  0.142355
# 0.406832  0         0.593168
# 0.798414  0.201586  0
#
# recurrent class: states 0 1 2
#
# time up to the first occurrence of state 0 distribution
# mean: 0   median: 0   mode: 0
# variance: 0   standard deviation: 0
#
# time up to the first occurrence of state 0 frequency distribution - sample size: 0
#
# time up to the first occurrence of state 1 distribution
# mean: 5.30301   median: 4   mode: 3
# variance: 32.0205   standard deviation: 5.65867   lower quartile: 2   upper quartile: 6
#
# time up to the first occurrence of state 1 frequency distribution - sample size: 30
# mean: 3.8   median: 3   mode: 1
# variance: 12.3724   standard deviation: 3.51744   lower quartile: 1   upper quartile: 5
#
# time up to the first occurrence of state 2 distribution
# mean: 12.989   median: 10   mode: 8
# variance: 88.8572   standard deviation: 9.42641   lower quartile: 7   upper quartile: 17
#
# time up to the first occurrence of state 2 frequency distribution - sample size: 30
# mean: 11.2333   median: 9   mode: 10
# variance: 101.426   standard deviation: 10.0711   lower quartile: 6   upper quartile: 12
#
# state 0 recurrence time distribution
# mean: 4.5702   median: 1   mode: 1
# variance: 56.5824   standard deviation: 7.52213   lower quartile: 1   upper quartile: 5
#
# state 0 recurrence time frequency distribution - sample size: 680
# mean: 4.09265   median: 1   mode: 1
# variance: 45.1593   standard deviation: 6.72007   lower quartile: 1   upper quartile: 4
#
# state 1 recurrence time distribution
# mean: 2.70369   median: 1   mode: 1
# variance: 26.1043   standard deviation: 5.10924   lower quartile: 1   upper quartile: 1
#
# state 1 recurrence time frequency distribution - sample size: 1095
# mean: 2.46484   median: 1   mode: 1
# variance: 21.1046   standard deviation: 4.59397   lower quartile: 1   upper quartile: 1
#
# state 2 recurrence time distribution
# mean: 2.4296   median: 1   mode: 1
# variance: 26.4298   standard deviation: 5.14099   lower quartile: 1   upper quartile: 1
#
# state 2 recurrence time frequency distribution - sample size: 1135
# mean: 2.17709   median: 1   mode: 1
# variance: 20.555   standard deviation: 4.53377   lower quartile: 1   upper quartile: 1
#
# STATE 0 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 6.47952   PROBABILITY : 0.722947
# mean: 3.48313   median: 3   mode: 3
# variance: 3.43474   standard deviation: 1.8533   lower quartile: 2   upper quartile: 5
# coefficient of skewness: 0.953138   coefficient of kurtosis: 1.21714
# coefficient of variation: 0.53208
#
# state 0 sojourn time frequency distribution - sample size: 200
# mean: 3.47   median: 3   mode: 4
# variance: 3.46643   standard deviation: 1.86184   lower quartile: 2   upper quartile: 5
#
# state 0 forward sojourn time distribution
# mean: 2.73456   median: 2   mode: 1
# variance: 2.98172   standard deviation: 1.72676   lower quartile: 1   upper quartile: 4
#
# final run - state 0 sojourn time frequency distribution - sample size: 9
# mean: 1.77778   median: 2   mode: 2
# variance: 0.444444   standard deviation: 0.666667   lower quartile: 1   upper quartile: 2
#
# STATE 1 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 7.96767   PROBABILITY : 0.621717
# mean: 5.84792   median: 5   mode: 5
# variance: 7.79763   standard deviation: 2.79242   lower quartile: 4   upper quartile: 7
# coefficient of skewness: 0.793897   coefficient of kurtosis: 0.881287
# coefficient of variation: 0.477507
#
# state 1 sojourn time frequency distribution - sample size: 187
# mean: 5.7754   median: 6   mode: 6
# variance: 7.18584   standard deviation: 2.68064   lower quartile: 4   upper quartile: 7
#
# state 1 forward sojourn time distribution
# mean: 4.0906   median: 4   mode: 1
# variance: 7.20494   standard deviation: 2.6842   lower quartile: 2   upper quartile: 6
#
# final run - state 1 sojourn time frequency distribution - sample size: 10
# mean: 4.5   median: 3   mode: 3
# variance: 19.6111   standard deviation: 4.42844   lower quartile: 2   upper quartile: 5
#
# STATE 2 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 2.0118   PROBABILITY : 0.203823
# mean: 8.85852   median: 7   mode: 4
# variance: 38.5556   standard deviation: 6.20932   lower quartile: 4   upper quartile: 12
# coefficient of skewness: 1.41923   coefficient of kurtosis: 3.00834
# coefficient of variation: 0.700943
#
# state 2 sojourn time frequency distribution - sample size: 128
# mean: 8.63281   median: 7   mode: 7
# variance: 37.557   standard deviation: 6.12838   lower quartile: 4   upper quartile: 11
#
# state 2 forward sojourn time distribution
# mean: 7.10515   median: 6   mode: 1
# variance: 33.7652   standard deviation: 5.81078   lower quartile: 3   upper quartile: 10
#
# final run - state 2 sojourn time frequency distribution - sample size: 11
# mean: 5.45455   median: 6   mode: 7
# variance: 14.6727   standard deviation: 3.8305   lower quartile: 2   upper quartile: 7
#
# number of runs of state 0 per length 100 sequence distribution
# mean: 6.92808   median: 7   mode: 7
# variance: 2.23694   standard deviation: 1.49564   lower quartile: 6   upper quartile: 8
# coefficient of skewness: 0.0649151   coefficient of kurtosis: -0.0317803
#
# number of runs of state 0 per sequence frequency distribution - sample size: 30
# mean: 6.96667   median: 7   mode: 8
# variance: 2.44713   standard deviation: 1.56433   lower quartile: 6   upper quartile: 8
# coefficient of skewness: -0.578127   coefficient of kurtosis: -0.0832256
#
# number of runs of state 1 per length 100 sequence distribution
# mean: 6.60997   median: 7   mode: 7
# variance: 2.03469   standard deviation: 1.42643   lower quartile: 6   upper quartile: 8
# coefficient of skewness: 0.0570521   coefficient of kurtosis: -0.0120113
#
# number of runs of state 1 per sequence frequency distribution - sample size: 30
# mean: 6.56667   median: 7   mode: 7
# variance: 1.63333   standard deviation: 1.27802   lower quartile: 6   upper quartile: 7
# coefficient of skewness: 0.0534122   coefficient of kurtosis: -0.779289
#
# number of runs of state 2 per length 100 sequence distribution
# mean: 4.65661   median: 5   mode: 5
# variance: 1.38233   standard deviation: 1.17572   lower quartile: 4   upper quartile: 5
# coefficient of skewness: 0.103861   coefficient of kurtosis: 0.0176902
#
# number of runs of state 2 per sequence frequency distribution - sample size: 30
# mean: 4.63333   median: 4   mode: 4
# variance: 0.929885   standard deviation: 0.964305   lower quartile: 4   upper quartile: 5
# coefficient of skewness: 1.57155   coefficient of kurtosis: 2.92787
#
# number of occurrences of state 0 per length 100 sequence distribution
# mean: 23.7512   median: 24   mode: 23
# variance: 39.238   standard deviation: 6.26403   lower quartile: 19   upper quartile: 28
# coefficient of skewness: 0.18138   coefficient of kurtosis: -0.0400641
#
# number of occurrences of state 0 per sequence frequency distribution - sample size: 30
# mean: 23.6667   median: 24   mode: 24
# variance: 43.1954   standard deviation: 6.57232   lower quartile: 20   upper quartile: 30
# coefficient of skewness: -0.244951   coefficient of kurtosis: -0.847716
#
# number of occurrences of state 1 per length 100 sequence distribution
# mean: 37.511   median: 37   mode: 37
# variance: 78.547   standard deviation: 8.86268   lower quartile: 31   upper quartile: 44
# coefficient of skewness: 0.0194452   coefficient of kurtosis: -0.111004
#
# number of occurrences of state 1 per sequence frequency distribution - sample size: 30
# mean: 37.5   median: 37   mode: 43
# variance: 87.1552   standard deviation: 9.33569   lower quartile: 30   upper quartile: 44
# coefficient of skewness: 0.0168915   coefficient of kurtosis: -0.554992
#
# number of occurrences of state 2 per length 100 sequence distribution
# mean: 38.7378   median: 39   mode: 38
# variance: 127.829   standard deviation: 11.3062   lower quartile: 31   upper quartile: 46
# coefficient of skewness: 0.0595598   coefficient of kurtosis: -0.151235
#
# number of occurrences of state 2 per sequence frequency distribution - sample size: 30
# mean: 38.8333   median: 40   mode: 45
# variance: 162.764   standard deviation: 12.7579   lower quartile: 28   upper quartile: 50
# coefficient of skewness: 0.160613   coefficient of kurtosis: -1.1214
#
# 1 OUTPUT_PROCESS
#
# OUTPUT_PROCESS 1 : CONTINUOUS_PARAMETRIC
#
# STATE 0 OBSERVATION_MODEL
# LINEAR_MODEL   INTERCEPT : -0.0421024   SLOPE : 8.08827e-05   (-0.000146341, 0.000308106)   STANDARD_DEVIATION : 1.0071
# correlation coefficient: 0.0262587   limit correlation coefficient: -/+0.0735937   critical probability: 0.05
#
# STATE 1 OBSERVATION_MODEL
# LINEAR_MODEL   INTERCEPT : -0.750273   SLOPE : 3.00576   (2.99857, 3.01295)   STANDARD_DEVIATION : 39.7747
# correlation coefficient: 0.999169   limit correlation coefficient: -/+0.0585047   critical probability: 0.05
#
# STATE 2 OBSERVATION_MODEL
# LINEAR_MODEL   INTERCEPT : 11.0979   SLOPE : 6.01004   (5.9347, 6.08538)   STANDARD_DEVIATION : 405.359
# correlation coefficient: 0.977031   limit correlation coefficient: -/+0.0573817   critical probability: 0.05
#
# sequence length frequency distribution - sample size: 30
# mean: 100   median: 100   mode: 100
# variance: 0   standard deviation: 0
#
# cumulative length: 3000
#
# log-likelihood for the state sequences: -16899.2   (normalized: -5.63308)
#
# state sequence entropy: 21.75   (normalized: 0.00724998)
#
# log-likelihood for the observed sequences: -16891   (normalized: -5.63032)
#
# 18 free parameters   2 * penalyzed log-likelihood (AIC): -33817.9
#
# 18 free parameters   2 * penalyzed log-likelihood (AICc): -33818.2
#
# 18 free parameters   2 * penalyzed log-likelihood (BIC): -33926
#
# 18 free parameters   2 * penalyzed log-likelihood (BICc): -33900.6
#
# 18 free parameters   2 * penalyzed log-likelihood (ICL): -33969.5
#
# 18 free parameters   2 * penalyzed log-likelihood (ICLc): -33944.1

# %% [markdown]
# ### Restore states

# %%
restored = hsmc_est_file.state_sequence_computation(seq_estim, True)
# Out:
# N.o. initial states in parallel: 0
#
# ERROR: 0 1.15047 inf
#
# ERROR: 1 0.991238 inf
#
# ERROR: 2 1.54302 inf
#
# ERROR: 3 0.382284 inf
#
# ERROR: 4 0.569538 inf
#
# ERROR: 5 0.762657 inf
#
# ERROR: 6 0.635904 inf
#
# ERROR: 7 0.837652 inf
#
# ERROR: 8 0.126471 inf
#
# ERROR: 9 0.802854 inf
#
# ERROR: 10 0.30887 inf
#
# ERROR: 11 1.32172 inf
#
# ERROR: 12 1.69704 inf
#
# ERROR: 13 1.14722 inf
#
# ERROR: 14 0.373237 inf
#
# ERROR: 15 0.701812 inf
#
# ERROR: 16 0.975776 inf
#
# ERROR: 17 0.0689797 inf
#
# ERROR: 18 0.774401 inf
#
# ERROR: 19 0.206215 inf
#
# ERROR: 20 1.21528 inf
#
# ERROR: 21 0.88962 inf
#
# ERROR: 22 1.40118 inf
#
# ERROR: 23 0.676442 inf
#
# ERROR: 24 0.471246 inf
#
# ERROR: 25 0.0921653 inf
#
# ERROR: 26 0.482937 inf
#
# ERROR: 27 0.433291 inf
#
# ERROR: 28 0.304617 inf
#
# ERROR: 29 0.405809 inf

# %%
all_rstate_s = []
for s in range(len(hsmd)):
    for t in range(len(hsmd[s])):
        all_rstate_s += [restored[s][t][0]]

all_rstate_s = np.array(all_rstate_s)
plt.plot(all_cov_s, all_obs_s, 'o', color=(0.9, 0.9, 0.9))
for k in sstate_s:
    cl = float(k)
    cl = np.array([cl, 15*cl, 20*cl]) / (20*(nb_states-1))
    plt.plot(all_cov_s[all_rstate_s==k], all_obs_s[all_rstate_s==k],  'o', 
             color=cl, label="restored state " + str(k))

plt.xlabel("covariate")
plt.ylabel("observations")
plt.legend()
plt.show()

# %% [markdown]
# **Restored error rate**

# %%
float(sum(all_rstate_s != all_state_s) / len(all_rstate_s))
# Out:
# 0.0033333333333333335

# %% [markdown]
# ## Estimate with default parameters

# %%
hsmc_est_default = Estimate(seq_estim, "HIDDEN_SEMI-MARKOV", "Ordinary", 3, "Irreducible", Nbiteration=300)
print(hsmc_est_default.display())
# Out:
# 0
# HIDDEN_SEMI-MARKOV_CHAIN
#
# 3 STATES
#
# INITIAL_PROBABILITIES
# 0.99998    1e-05      1e-05
#
# TRANSITION_PROBABILITIES
# 0          0.703068   0.296932
# 0.668368   0          0.331632
# 0.963403   0.0365972  0
#
# recurrent class: states 0 1 2
#
# time up to the first occurrence of state 0 distribution
# mean: 0   median: 0   mode: 0
# variance: 0   standard deviation: 0
#
# time up to the first occurrence of state 0 frequency distribution - sample size: 0
#
# time up to the first occurrence of state 1 distribution
# mean: 9.49627   median: 4   mode: 3
# variance: 141.014   standard deviation: 11.8749   lower quartile: 3   upper quartile: 12
#
# time up to the first occurrence of state 1 frequency distribution - sample size: 30
# mean: 2.93333   median: 3   mode: 1
# variance: 2.75402   standard deviation: 1.65952   lower quartile: 1   upper quartile: 4
#
# time up to the first occurrence of state 2 distribution
# mean: 18.0434   median: 12   mode: 3
# variance: 329.5   standard deviation: 18.1521   lower quartile: 5   upper quartile: 25
#
# time up to the first occurrence of state 2 frequency distribution - sample size: 30
# mean: 45.9667   median: 44.5   mode: 39
# variance: 94.5851   standard deviation: 9.72548   lower quartile: 39   upper quartile: 53
#
# state 0 recurrence time distribution
# mean: 4.53169   median: 1   mode: 1
# variance: 56.8525   standard deviation: 7.54006   lower quartile: 1   upper quartile: 4
#
# state 0 recurrence time frequency distribution - sample size: 680
# mean: 4.09265   median: 1   mode: 1
# variance: 45.1593   standard deviation: 6.72007   lower quartile: 1   upper quartile: 4
#
# state 1 recurrence time distribution
# mean: 2.51216   median: 1   mode: 1
# variance: 39.4468   standard deviation: 6.28067   lower quartile: 1   upper quartile: 1
#
# state 1 recurrence time frequency distribution - sample size: 1216
# mean: 1.53289   median: 1   mode: 1
# variance: 5.1199   standard deviation: 2.26272   lower quartile: 1   upper quartile: 1
#
# state 2 recurrence time distribution
# mean: 2.6196   median: 1   mode: 1
# variance: 57.4644   standard deviation: 7.58053   lower quartile: 1   upper quartile: 1
#
# state 2 recurrence time frequency distribution - sample size: 1014
# mean: 1.55325   median: 1   mode: 1
# variance: 7.83675   standard deviation: 2.79942   lower quartile: 1   upper quartile: 1
#
# STATE 0 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 6.78584   PROBABILITY : 0.730998
# mean: 3.49714   median: 3   mode: 3
# variance: 3.41607   standard deviation: 1.84826   lower quartile: 2   upper quartile: 5
# coefficient of skewness: 0.939253   coefficient of kurtosis: 1.17693
# coefficient of variation: 0.528506
#
# state 0 sojourn time frequency distribution - sample size: 200
# mean: 3.47   median: 3   mode: 4
# variance: 3.46643   standard deviation: 1.86184   lower quartile: 2   upper quartile: 5
#
# state 0 forward sojourn time distribution
# mean: 2.73693   median: 2   mode: 1
# variance: 2.96981   standard deviation: 1.72331   lower quartile: 1   upper quartile: 4
#
# final run - state 0 sojourn time frequency distribution - sample size: 9
# mean: 1.77778   median: 2   mode: 2
# variance: 0.444444   standard deviation: 0.666667   lower quartile: 1   upper quartile: 2
#
# STATE 1 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 1.30363   PROBABILITY : 0.144365
# mean: 8.72644   median: 7   mode: 2
# variance: 53.5202   standard deviation: 7.31575   lower quartile: 3   upper quartile: 12
# coefficient of skewness: 1.757   coefficient of kurtosis: 4.62123
# coefficient of variation: 0.838343
#
# state 1 sojourn time frequency distribution - sample size: 138
# mean: 9.02899   median: 7   mode: 5
# variance: 52.8751   standard deviation: 7.27152   lower quartile: 5   upper quartile: 10
#
# state 1 forward sojourn time distribution
# mean: 7.92918   median: 6   mode: 1
# variance: 49.8502   standard deviation: 7.06047   lower quartile: 3   upper quartile: 11
#
# final run - state 1 sojourn time frequency distribution - sample size: 0
#
# STATE 2 OCCUPANCY_DISTRIBUTION
# NEGATIVE_BINOMIAL   INF_BOUND : 1   PARAMETER : 2.73265   PROBABILITY : 0.210171
# mean: 11.2694   median: 10   mode: 7
# variance: 48.862   standard deviation: 6.99013   lower quartile: 6   upper quartile: 15
# coefficient of skewness: 1.2183   coefficient of kurtosis: 2.21614
# coefficient of variation: 0.620277
#
# state 2 sojourn time frequency distribution - sample size: 84
# mean: 10.2619   median: 9   mode: 7
# variance: 35.0149   standard deviation: 5.91734   lower quartile: 6   upper quartile: 13
#
# state 2 forward sojourn time distribution
# mean: 8.30231   median: 7   mode: 1
# variance: 42.5211   standard deviation: 6.52082   lower quartile: 3   upper quartile: 11
#
# final run - state 2 sojourn time frequency distribution - sample size: 21
# mean: 8.66667   median: 7   mode: 2.5
# variance: 50.0333   standard deviation: 7.07342   lower quartile: 3   upper quartile: 13
#
# number of runs of state 0 per length 100 sequence distribution
# mean: 6.96345   median: 7   mode: 7
# variance: 2.37912   standard deviation: 1.54244   lower quartile: 6   upper quartile: 8
# coefficient of skewness: 0.164608   coefficient of kurtosis: 0.000644334
#
# number of runs of state 0 per sequence frequency distribution - sample size: 30
# mean: 6.96667   median: 7   mode: 8
# variance: 2.44713   standard deviation: 1.56433   lower quartile: 6   upper quartile: 8
# coefficient of skewness: -0.578127   coefficient of kurtosis: -0.0832256
#
# number of runs of state 1 per length 100 sequence distribution
# mean: 4.85407   median: 5   mode: 5
# variance: 2.42266   standard deviation: 1.55649   lower quartile: 4   upper quartile: 6
# coefficient of skewness: 0.232537   coefficient of kurtosis: 0.0326194
#
# number of runs of state 1 per sequence frequency distribution - sample size: 30
# mean: 4.6   median: 5   mode: 5
# variance: 1.76552   standard deviation: 1.32873   lower quartile: 4   upper quartile: 6
# coefficient of skewness: -0.703042   coefficient of kurtosis: 0.259668
#
# number of runs of state 2 per length 100 sequence distribution
# mean: 3.48   median: 3   mode: 3
# variance: 1.63138   standard deviation: 1.27725   lower quartile: 3   upper quartile: 4
# coefficient of skewness: 0.150988   coefficient of kurtosis: -0.0399026
#
# number of runs of state 2 per sequence frequency distribution - sample size: 30
# mean: 3.5   median: 3   mode: 3
# variance: 0.948276   standard deviation: 0.973795   lower quartile: 3   upper quartile: 4
# coefficient of skewness: 0.240057   coefficient of kurtosis: -1.01074
#
# number of occurrences of state 0 per length 100 sequence distribution
# mean: 23.9683   median: 24   mode: 23
# variance: 41.0627   standard deviation: 6.40802   lower quartile: 19   upper quartile: 28
# coefficient of skewness: 0.233887   coefficient of kurtosis: -0.0086653
#
# number of occurrences of state 0 per sequence frequency distribution - sample size: 30
# mean: 23.6667   median: 24   mode: 24
# variance: 43.1954   standard deviation: 6.57232   lower quartile: 20   upper quartile: 30
# coefficient of skewness: -0.244951   coefficient of kurtosis: -0.847716
#
# number of occurrences of state 1 per length 100 sequence distribution
# mean: 39.6009   median: 39   mode: 38
# variance: 212.965   standard deviation: 14.5933   lower quartile: 29   upper quartile: 50
# coefficient of skewness: 0.136996   coefficient of kurtosis: -0.276567
#
# number of occurrences of state 1 per sequence frequency distribution - sample size: 30
# mean: 41.5333   median: 43   mode: 50
# variance: 60.1195   standard deviation: 7.75368   lower quartile: 37   upper quartile: 49
# coefficient of skewness: -0.769442   coefficient of kurtosis: -0.172345
#
# number of occurrences of state 2 per length 100 sequence distribution
# mean: 36.4308   median: 36   mode: 36
# variance: 219.665   standard deviation: 14.8211   lower quartile: 26   upper quartile: 47
# coefficient of skewness: 0.0952237   coefficient of kurtosis: -0.311596
#
# number of occurrences of state 2 per sequence frequency distribution - sample size: 30
# mean: 34.8   median: 33   mode: 26
# variance: 67.4759   standard deviation: 8.21437   lower quartile: 29   upper quartile: 42
# coefficient of skewness: -0.0637023   coefficient of kurtosis: -1.13631
#
# theoretical state probabilities: 0.239702 0.395999 0.364299
# restoration state probabilities: 0.236667 0.415333 0.348
#
# 1 OUTPUT_PROCESS
#
# OUTPUT_PROCESS 1 : CONTINUOUS_PARAMETRIC
#
# STATE 0 OBSERVATION_DISTRIBUTION
# GAUSSIAN   MEAN : 0.000382617   STANDARD_DEVIATION : 1.0017
# variance: 1.00341
#
# STATE 1 OBSERVATION_DISTRIBUTION
# GAUSSIAN   MEAN : 1323.95   STANDARD_DEVIATION : 756.422
# variance: 572175
#
# STATE 2 OBSERVATION_DISTRIBUTION
# GAUSSIAN   MEAN : 4169.53   STANDARD_DEVIATION : 1381.93
# variance: 1.90974e+06
#
# distances between observation distributions for consecutive states
# _         0.998237  0.998968
# 0.998237  _         0.826876
# 0.998968  0.826876  _
#
# sequence length frequency distribution - sample size: 30
# mean: 100   median: 100   mode: 100
# variance: 0   standard deviation: 0
#
# cumulative length: 3000
#
# log-likelihood for the state sequences: -21359.6   (normalized: -7.11986)
#
# state sequence entropy: 87.8812   (normalized: 0.0292937)
#
# log-likelihood for the observed sequences: -21320.3   (normalized: -7.10676)
#
# 15 free parameters   2 * penalyzed log-likelihood (AIC): -42670.6
#
# 15 free parameters   2 * penalyzed log-likelihood (AICc): -42670.7
#
# 15 free parameters   2 * penalyzed log-likelihood (BIC): -42760.7
#
# 15 free parameters   2 * penalyzed log-likelihood (BICc): -42738
#
# 15 free parameters   2 * penalyzed log-likelihood (ICL): -42936.4
#
# 15 free parameters   2 * penalyzed log-likelihood (ICLc): -42913.7
#
#
# Initializations
# state 0: 1938
# state 1: 2004.83
# state 2: 2071.65
#
# iteration 1   log-likelihood for the observed sequences: -26925.3
# iteration 2   log-likelihood for the observed sequences: -26448.6
# iteration 3   log-likelihood for the observed sequences: -25858.7
# iteration 4   log-likelihood for the observed sequences: -25671.1
# iteration 5   log-likelihood for the observed sequences: -25519
# iteration 6   log-likelihood for the observed sequences: -25312.3
# iteration 7   log-likelihood for the observed sequences: -25108.5
# iteration 8   log-likelihood for the observed sequences: -24902.1
# iteration 9   log-likelihood for the observed sequences: -24686.2
# iteration 10   log-likelihood for the observed sequences: -24564.7
# iteration 11   log-likelihood for the observed sequences: -24531
# iteration 12   log-likelihood for the observed sequences: -24517
# iteration 13   log-likelihood for the observed sequences: -24502.7
# iteration 14   log-likelihood for the observed sequences: -24480.7
# iteration 15   log-likelihood for the observed sequences: -24448.2
# iteration 16   log-likelihood for the observed sequences: -24409.6
# iteration 17   log-likelihood for the observed sequences: -24359.1
# iteration 18   log-likelihood for the observed sequences: -24274.6
# iteration 19   log-likelihood for the observed sequences: -24164
# iteration 20   log-likelihood for the observed sequences: -24067.3
# iteration 21   log-likelihood for the observed sequences: -23949.4
# iteration 22   log-likelihood for the observed sequences: -23808
# iteration 23   log-likelihood for the observed sequences: -23615.1
# iteration 24   log-likelihood for the observed sequences: -23258.9
# iteration 25   log-likelihood for the observed sequences: -22659.6
# iteration 26   log-likelihood for the observed sequences: -21710.1
# iteration 27   log-likelihood for the observed sequences: -21347.5
# iteration 28   log-likelihood for the observed sequences: -21346.1
# iteration 29   log-likelihood for the observed sequences: -21344.8
# iteration 30   log-likelihood for the observed sequences: -21343.2
# iteration 31   log-likelihood for the observed sequences: -21341.4
# iteration 32   log-likelihood for the observed sequences: -21339.1
# iteration 33   log-likelihood for the observed sequences: -21336.4
# iteration 34   log-likelihood for the observed sequences: -21333.1
# iteration 35   log-likelihood for the observed sequences: -21329.8
# iteration 36   log-likelihood for the observed sequences: -21326.9
# iteration 37   log-likelihood for the observed sequences: -21324.8
# iteration 38   log-likelihood for the observed sequences: -21323.4
# iteration 39   log-likelihood for the observed sequences: -21322.3
# iteration 40   log-likelihood for the observed sequences: -21321.7
# iteration 41   log-likelihood for the observed sequences: -21321.2
# iteration 42   log-likelihood for the observed sequences: -21320.9
# iteration 43   log-likelihood for the observed sequences: -21320.7
# iteration 44   log-likelihood for the observed sequences: -21320.5
# iteration 45   log-likelihood for the observed sequences: -21320.5
# iteration 46   log-likelihood for the observed sequences: -21320.4
# iteration 47   log-likelihood for the observed sequences: -21320.3
# iteration 48   log-likelihood for the observed sequences: -21320.3
#
# 48 iterations
#
# complete/censored state occupancy weights
# state 0: 198.736, 8.9993  (0.956679, 0.0433211)
# state 1: 142.641, 0.213301  (0.998507, 0.00149313)
# state 2: 85.528, 20.7874  (0.804474, 0.195526)
#
# N.o. initial states in parallel: 0
#
# ERROR: 0 1.42281 inf
#
# ERROR: 1 3.00315 inf
#
# ERROR: 3 3.15506 inf
#
# ERROR: 4 3.2455 inf
#
# ERROR: 5 3.52163 inf
#
# ERROR: 6 3.74485 inf
#
# ERROR: 7 2.19835 inf
#
# ERROR: 8 1.74344 inf
#
# ERROR: 9 0.705814 inf
#
# ERROR: 10 5.03724 inf
#
# ERROR: 11 3.33928 inf
#
# ERROR: 12 0.862523 inf
#
# ERROR: 13 4.42265 inf
#
# ERROR: 14 3.02721 inf
#
# ERROR: 15 4.21042 inf
#
# ERROR: 16 4.44897 inf
#
# ERROR: 18 3.38193 inf
#
# ERROR: 19 1.91364 inf
#
# ERROR: 21 4.73706 inf
#
# ERROR: 22 4.42464 inf
#
# ERROR: 23 2.24926 inf
#
# ERROR: 24 2.96011 inf
#
# ERROR: 25 3.09241 inf
#
# ERROR: 26 4.20715 inf
#
# ERROR: 27 2.32648 inf
#
# ERROR: 28 1.05182 inf
#
# ERROR: 29 1.52913 inf
#
# log-likelihood for the state sequences: -21359.6
#
# posterior state sequence probability
# sequence 1: 0.684975
# sequence 2: 0.364617
# sequence 3: 0.106543
# sequence 4: 0.260427
# sequence 5: 0.191176
# sequence 6: 0.251329
# sequence 7: 0.158688
# sequence 8: 0.339885
# sequence 9: 0.50945
# sequence 10: 0.864422
# sequence 11: 0.103373
# sequence 12: 0.254003
# sequence 13: 0.792862
# sequence 14: 0.14991
# sequence 15: 0.352277
# sequence 16: 0.088701
# sequence 17: 0.0645977
# sequence 18: 0.259901
# sequence 19: 0.207395
# sequence 20: 0.621683
# sequence 21: 0.652971
# sequence 22: 0.056781
# sequence 23: 0.0936673
# sequence 24: 0.543635
# sequence 25: 0.40343
# sequence 26: 0.269477
# sequence 27: 0.191865
# sequence 28: 0.280291
# sequence 29: 0.760846
# sequence 30: 0.618684
#
# sup norm distance: 0.998237 0.998749
#
# sup norm distance: 0.998968 0.99948
#
# sup norm distance: 0.826876 0.827386

# %% [markdown]
# Estimate Gaussian distributions instead of linear models
